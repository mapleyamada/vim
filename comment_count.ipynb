# %%
# %matplotlib inline

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('ggplot') 

fd = pd.read_csv('./ramenbu201807.csv')

fd
# Out:
#                      Date           Name  \
# 0      2018-07-01 0:02:24   hajime.shoji
# 1      2018-07-01 0:02:27   hajime.shoji
# 2      2018-07-01 0:03:38   wakana.kaizu
# 3      2018-07-01 0:12:55   yuuki.shinpo
# 4      2018-07-01 0:12:56   yuuki.shinpo
# 5      2018-07-01 2:30:39   ikebi.ishida
# 6     2018-07-03 13:02:45    hikaru.iida
# 7     2018-07-03 13:03:27    hikaru.iida
# 8     2018-07-03 13:04:05   hajime.shoji
# 9     2018-07-03 13:05:05   yuuki.shinpo
# 10    2018-07-03 13:07:02   hajime.shoji
# 11    2018-07-03 13:16:33   wakana.kaizu
# 12    2018-07-03 13:17:03   hajime.shoji
# 13    2018-07-03 13:24:19    hikaru.iida
# 14    2018-07-03 13:28:38   hajime.shoji
# 15    2018-07-03 13:28:44   hajime.shoji
# 16    2018-07-03 13:30:28   wakana.kaizu
# 17    2018-07-03 13:31:22   yuuki.shinpo
# 18    2018-07-03 13:31:33   hajime.shoji
# 19    2018-07-03 13:45:48   ikebi.ishida
# 20    2018-07-03 13:46:35   yuuki.shinpo
# 21    2018-07-03 13:59:23   yuuki.shinpo
# ...

# %%
fd.count()
# Out:
# Date       1898
# Name       1898
# Comment    1889
# Json       1898
# dtype: int64

# %%
print(fd['Name'].value_counts())
fd['Name'].value_counts().plot.bar(y=['発言回数'], alpha=0.6, figsize=(12,3))
# Out:
# yuuki.shinpo        754
# hajime.shoji        399
# wakana.kaizu        246
# hikaru.iida         216
# ikebi.ishida        107
# shizuku.imano        76
# maple-hara           45
# keiko.oshiumi        34
# akitomo.kibihara     10
# yukina.ootake         9
# maple-kage            2
# Name: Name, dtype: int64
